# %% [markdown]
# # Corporate Sustainability

# %%
import pandas as pd
ghgp = pd.read_csv("ghgp_data_by_year.xlsx - Direct Emitters.csv")
ghgp.head()
# Out:
#   Summary data collected by the Greenhouse Gas Reporting Program  \
# 0  This data was reported to EPA by facilities as...
# 1  All emissions data is presented in units of me...
# 2                                        Facility Id
# 3                                            1004377
# 4                                            1010040
#
#      Unnamed: 1                      Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           NaN                             NaN        NaN        NaN
# 1           NaN                             NaN        NaN        NaN
# 2        FRS Id                   Facility Name       City      State
# 3  110043803578  121 REGIONAL DISPOSAL FACILITY    MELISSA         TX
# 4  110071159872               15-18565/15-18662     Hazard         KY
#
#   Unnamed: 5                Unnamed: 6     Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN                       NaN            NaN        NaN        NaN
# ...

# %%
refinitiv = pd.read_csv("CS216 Data from Refinitiv.xlsx - Sheet1.csv")
refinitiv.head()
# Out:
#   #NAME? Company Common Name                 TRBC Industry Name  \
# 0    NaN                 NaN                                NaN
# 1    NaN                 NaN                                NaN
# 2   DE.N          Deere & Co         Heavy Machinery & Vehicles
# 3  FTV.N        Fortive Corp   Industrial Machinery & Equipment
# 4   ET.N  Energy Transfer LP  Oil & Gas Transportation Services
#
#     Country of Headquarters       Country of Exchange Company Market Cap  \
# 0                       NaN                       NaN          22/3/2023
# 1                       NaN                       NaN                NaN
# 2  United States of America  United States of America        119.2963839
# 3  United States of America  United States of America        23.28992775
# 4  United States of America  United States of America        37.47553043
#
#      ESG Score EBIT Margin - % EBIT Margin - %.1 EBIT Margin - %.2  ...  \
# ...
